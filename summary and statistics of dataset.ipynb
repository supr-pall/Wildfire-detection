# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-64b7947f-1ac1-4589-9f7d-9c0b53c0f097" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-64b7947f-1ac1-4589-9f7d-9c0b53c0f097">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

df = pd.read_csv("wildfire_dataset.csv")
df.head()
# Out:
#    Temperature   Humidity  Wind Speed   Rainfall  Region Risk Level  \
# 0    29.363503  65.852937    7.405317  10.381636                  2
# 1    43.767858  52.887709   21.676038   9.583638                  2
# 2    38.299849  34.762209   34.917833   0.512841                  2
# 3    34.966462  75.103602   29.288995   6.824957                  1
# 4    23.900466  64.778494   32.262446   7.603912                  1
#
#    Wildfire Occurrence
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %%
df.head()
# Out:
#    Temperature   Humidity  Wind Speed   Rainfall  Region Risk Level  \
# 0    29.363503  65.852937    7.405317  10.381636                  2
# 1    43.767858  52.887709   21.676038   9.583638                  2
# 2    38.299849  34.762209   34.917833   0.512841                  2
# 3    34.966462  75.103602   29.288995   6.824957                  1
# 4    23.900466  64.778494   32.262446   7.603912                  1
#
#    Wildfire Occurrence
# 0                    0
# 1                    1
# 2                    0
# 3                    0
# 4                    0

# %%
df.shape
# Out:
# (500, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 6 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Temperature          500 non-null    float64
#  1   Humidity             500 non-null    float64
#  2   Wind Speed           500 non-null    float64
#  3   Rainfall             500 non-null    float64
#  4   Region Risk Level    500 non-null    int64
#  5   Wildfire Occurrence  500 non-null    int64
# dtypes: float64(4), int64(2)
# memory usage: 23.6 KB

# %%
df.describe()
# Out:
#        Temperature    Humidity  Wind Speed    Rainfall  Region Risk Level  \
# count   500.000000  500.000000  500.000000  500.000000         500.000000
# mean     32.464043   48.556112   20.702325    9.929530           0.976000
# std       7.467210   22.839477   11.887717    5.740197           0.827523
# min      20.126540   10.370562    0.197599    0.064365           0.000000
# 25%      26.031992   28.327940    9.649122    4.821485           0.000000
# 50%      32.829094   47.745725   21.589533   10.177827           1.000000
# 75%      38.903122   68.106946   31.093750   14.747525           2.000000
# max      44.824120   89.977414   39.976549   19.966950           2.000000
#
#        Wildfire Occurrence
# count           500.000000
# mean              0.302000
# std               0.459585
# min               0.000000
# 25%               0.000000
# 50%               0.000000
# 75%               1.000000
# max               1.000000

# %%
df.isnull().sum()
# Out:
# Temperature            0
# Humidity               0
# Wind Speed             0
# Rainfall               0
# Region Risk Level      0
# Wildfire Occurrence    0
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10,6))
sns.heatmap(df.corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
mean_values = df.mean()
median_values = df.median()
std_values = df.std()

print("Mean:\n", mean_values)
print("Median:\n", median_values)
print("Standard Deviation:\n", std_values)
# Out:
# Mean:
#  Temperature            32.464043
# Humidity               48.556112
# Wind Speed             20.702325
# Rainfall                9.929530
# Region Risk Level       0.976000
# Wildfire Occurrence     0.302000
# dtype: float64
# Median:
#  Temperature            32.829094
# Humidity               47.745725
# Wind Speed             21.589533
# Rainfall               10.177827
# Region Risk Level       1.000000
# Wildfire Occurrence     0.000000
# dtype: float64
# Standard Deviation:
#  Temperature             7.467210
# Humidity               22.839477
# Wind Speed             11.887717
# Rainfall                5.740197
# Region Risk Level       0.827523
# Wildfire Occurrence     0.459585
# dtype: float64

# %%
print("Skewness:\n", df.skew())
print("Kurtosis:\n", df.kurt())
# Out:
# Skewness:
#  Temperature           -0.025572
# Humidity               0.104487
# Wind Speed            -0.101973
# Rainfall              -0.020126
# Region Risk Level      0.044774
# Wildfire Occurrence    0.865107
# dtype: float64
# Kurtosis:
#  Temperature           -1.255427
# Humidity              -1.194901
# Wind Speed            -1.249460
# Rainfall              -1.178564
# Region Risk Level     -1.538789
# Wildfire Occurrence   -1.256632
# dtype: float64

# %% [markdown]
# Let \( X = \{x_1, x_2, \dots, x_n\} \) be a numerical feature, such as temperature or humidity.
#
# **Mean**
# \[
# \mu = \frac{1}{n} \sum_{i=1}^{n} x_i
# \]
#
# **Variance**
# \[
# \sigma^2 = \frac{1}{n} \sum_{i=1}^{n} (x_i - \mu)^2
# \]
#
# **Standard Deviation**
# \[
# \sigma = \sqrt{\sigma^2}
# \]
#
# **Pearson Correlation Coefficient**
# \[
# r = \frac{\sum_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum_{i=1}^{n}(x_i - \bar{x})^2} \cdot \sqrt{\sum_{i=1}^{n}(y_i - \bar{y})^2}}
# \]

# %% [markdown]
# Let \( X = \{x_1, x_2, \dots, x_n\} \) be a numerical feature, such as temperature or humidity.
#
# **Mean**
# \[
# \mu = \frac{1}{n} \sum_{i=1}^{n} x_i
# \]
#
# **Variance**
# \[
# \sigma^2 = \frac{1}{n} \sum_{i=1}^{n} (x_i - \mu)^2
# \]
#
# **Standard Deviation**
# \[
# \sigma = \sqrt{\sigma^2}
# \]
#
# **Pearson Correlation Coefficient**
# \[
# r = \frac{\sum_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y})}{\sqrt{\sum_{i=1}^{n}(x_i - \bar{x})^2} \cdot \sqrt{\sum_{i=1}^{n}(y_i - \bar{y})^2}}
# \]

# %% [markdown]
# Let \( X = \{x_1, x_2, \dots, x_n\} \) be a numerical feature, such as temperature or humidity.
#
# ### Mean
# $$ \mu = \frac{1}{n} \sum_{i=1}^{n} x_i $$
#
# ### Variance
# $$ \sigma^2 = \frac{1}{n} \sum_{i=1}^{n} (x_i - \mu)^2 $$
#
# ### Standard Deviation
# $$ \sigma = \sqrt{\sigma^2} $$
#
# ### Pearson Correlation Coefficient
# $$
# r = \frac{\sum_{i=1}^{n} (x_i - \bar{x})(y_i - \bar{y})}
# {\sqrt{\sum_{i=1}^{n} (x_i - \bar{x})^2} \cdot \sqrt{\sum_{i=1}^{n} (y_i - \bar{y})^2}}
# $$
